# %%
import numpy as np
from itertools import combinations
from sage.all import QQ, NumberField, PolynomialRing

# %%
def find_feasible_vertices(A, b):
    """Find vertices of polytope defined by A @ x ≤ b"""
    num_vars = A.shape[1]
    vertices = []
    
    for indices in combinations(range(len(A)), num_vars):
        A_sub = A[list(indices)]
        b_sub = b[list(indices)]
        
        try:
            vertex = np.linalg.solve(A_sub, b_sub)
            if np.all(A @ vertex <= b + 1e-6):
                vertices.append(vertex)
        except np.linalg.LinAlgError:
            continue
    
    return np.unique(np.round(vertices, decimals=6), axis=0) if vertices else np.array([])


def twoParts(alpha,embeddings):
    """FIND ALL TWO PARTITION OF ALPHA"""


    """FEILD INPUT Calculation"""
  
    K = alpha.parent().fraction_field()  

    if not K.is_totally_real():
        raise ValueError("Field must be totally real")
    
    O = K.maximal_order()
    basis = O.basis()
    """FEILD INPUT Calculation Over"""

    """BOUNDS CALCULATION"""
    embedding_data = []
    for sig in embeddings:
        a_img = sig(basis[0]) if len(basis) > 0 else 0
        b_img = sig(basis[1]) if len(basis) > 1 else 0
        c_img = sig(basis[2]) if len(basis) > 2 else 0
        alpha_img = sig(alpha)
        embedding_data.append((a_img,b_img,c_img, alpha_img))
 
    A_ineq = []
    b_ineq = []
    epsilon = 10^(-6)
    
    for (a,b,c,Alpha) in embedding_data:
        A_ineq.append([float(a),float(b),float(c)])
        b_ineq.append(float(Alpha) - epsilon)
        A_ineq.append([-float(a),-float(b), -float(c)])
        b_ineq.append(-epsilon)

    A_ineq = np.array(A_ineq)
    b_ineq = np.array(b_ineq)
    
    vertices = find_feasible_vertices(A_ineq, b_ineq)
    
    if not vertices.size:
        return 0, []
    
    bound=[]
    
    for i in range(3):
        a=[]
        a.append(np.floor(np.min(vertices[:,i])))
        a.append(np.ceil(np.max(vertices[:,i])))
        bound.append(a)
  
    k1_min, k1_max = bound[0][0],bound[0][1]
    k2_min, k2_max = bound[1][0],bound[1][1]
    k3_min, k3_max = bound[2][0],bound[2][1]

    """BOUNDS CALCULATION OVER"""

    """FINDING PARTITIONS"""
    partitions = []
    for k1 in range(int(k1_min),int(k1_max)+1):
        for k2 in range(int(k2_min),int(k2_max)+1):
            for k3 in range(int(k3_min),int(k3_max)+1):
                beta= k1*basis[0] + k2*basis[1] + k3*basis[2]
         
                Y= alpha - beta
            
                if beta == 0 or Y == 0:
                    continue
            
                if beta.is_totally_positive() and Y.is_totally_positive():
                    partitions.append((beta, Y))
    
    unique_partitions = []
    seen = set()
    for pair in partitions:
        if pair not in seen and pair[::-1] not in seen:
            seen.add(pair)
            unique_partitions.append(pair)
    
    return unique_partitions


def allParts(alpha, embeddings, memo=None):
    """
    Recursively find all partitions of alpha into sums of totally positive elements.
    Stops recursion when no further partitions are possible.
    Returns the number of unique partitions.
    Memo store all partitions of parts of alpha and alpha
    """
    if memo is None:
        memo = {}                               
    
    alpha_key = tuple(alpha.list())
    if alpha_key in memo:
        return memo[alpha_key]
    
    if not alpha.is_totally_positive():
        raise ValueError("alpha is not totally positive")
    
    partitions = twoParts(alpha, embeddings)

    all_partitions = []
    
    for beta, gamma in partitions:
        all_partitions.append([beta, gamma])
    
        beta_partitions = allParts(beta, embeddings, memo)
        for p in beta_partitions:
            all_partitions.append(p + [gamma])
        
        gamma_partitions = allParts(gamma, embeddings, memo)
        for p in gamma_partitions:
            all_partitions.append([beta] + p)

    unique_partitions = []
    seen = set()
    for partition in all_partitions:
        sorted_part = tuple(sorted(tuple(x.list()) for x in partition))
        
        if sorted_part not in seen:
            seen.add(sorted_part)
            unique_partitions.append(partition)
    
    memo[alpha_key] = unique_partitions

    return unique_partitions

def memolength(memo):
    """CALCULATES LENGTH OF MEMO"""
    lmemo = {}
    for key in memo:
        lmemo[key] = len(memo[key])
    return lmemo


def Partitions(alpha, embeddings):
    memo={}
    if alpha.is_totally_positive():
        partitions = allParts(alpha,embeddings,memo)
        return len(partitions)+1,memo
    else:
        return 'The number given is not totally positive'




#R.<x> = QQ[]
#K.<x> = NumberField(x^3-3*x-1)
#O = K.ring_of_integers()
#embeddings = K.embeddings(QQbar)  

#alpha=5+x
#alpha1 = O.coordinates(alpha)[0]*O.basis()[0] + O.coordinates(alpha)[1]*O.basis()[1]

#l,fmemo=Partitions(alpha1, embeddings)

#print(fmemo)

# %%
import csv

def Partition_Function(Poly, a, b,c):
    R.<x> = QQ[]
    K.<x> = NumberField(Poly)
    O = K.ring_of_integers()
    embeddings = K.embeddings(QQbar) 
    alpha = a + b * x+ c * x^2
    l, fmemo = Partitions(alpha, embeddings)
    
    # Writing to CSV file
    with open("Cubic_x3-3x-1_4.csv", mode="a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([b,c,l])

# %%
R.<x> = QQ[]
Poly=x^3-3*x-1
for i in range(7):
    for j in range(7):
        try:
            Partition_Function(Poly,4,i,j)
        except ValueError:
            continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 for j in range(Integer(7)):
#       5     try:
# ----> 6         Partition_Function(Poly,Integer(4),i,j)
#       7     except ValueError:
#       8         continue
#
# Cell In[4], line 9, in Partition_Function(Poly, a, b, c)
#       7 embeddings = K.embeddings(QQbar)
#       8 alpha = a + b * x+ c * x**Integer(2)
# ----> 9 l, fmemo = Partitions(alpha, embeddings)
#      11 # Writing to CSV file
#      12 with open("Cubic_x3-3x-1_4.csv", mode="a", newline="") as file:
#
# Cell In[3], line 157, in Partitions(alpha, embeddings)
#     155 memo={}
#     156 if alpha.is_totally_positive():
# --> 157     partitions = allParts(alpha,embeddings,memo)
#     158     return len(partitions)+Integer(1),memo
#     159 else:
#
# Cell In[3], line 118, in allParts(alpha, embeddings, memo)
#     115 if not alpha.is_totally_positive():
#     116     raise ValueError("alpha is not totally positive")
# --> 118 partitions = twoParts(alpha, embeddings)
#     120 all_partitions = []
#     122 for beta, gamma in partitions:
#
# Cell In[3], line 81, in twoParts(alpha, embeddings)
#      79 for k2 in range(int(k2_min),int(k2_max)+Integer(1)):
#      80     for k3 in range(int(k3_min),int(k3_max)+Integer(1)):
# ---> 81         beta= k1*basis[Integer(0)] + k2*basis[Integer(1)] + k3*basis[Integer(2)]
#      83         Y= alpha - beta
#      85         if beta == Integer(0) or Y == Integer(0):
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/element.pyx:1518, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:20402)()
#    1516     integer_check_long_py(left, &value, &err)
#    1517     if not err:
# -> 1518         return (<Element>right)._mul_long(value)
#    1519     return coercion_model.bin_op(left, right, mul)
#    1520 except TypeError:
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/element.pyx:2419, in sage.structure.element.ModuleElement._mul_long (build/cythonized/sage/structure/element.c:24647)()
#    2417     if n == 1:
#    2418         return self
# -> 2419     return coercion_model.bin_op(self, n, mul)
#    2420
#    2421 # rmul -- left * self
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/coerce.pyx:1234, in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:15947)()
#    1232 # Now coerce to a common parent and do the operation there
#    1233 try:
# -> 1234     xy = self.canonical_coercion(x, y)
#    1235 except TypeError:
#    1236     self._record_exception()
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/coerce.pyx:1350, in sage.structure.coerce.CoercionModel.canonical_coercion (build/cythonized/sage/structure/coerce.c:17399)()
#    1348     x_elt = x
#    1349 if y_map is not None:
# -> 1350     y_elt = (<Map>y_map)._call_(y)
#    1351 else:
#    1352     y_elt = y
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/rings/number_field/order.py:1608, in Order_absolute._element_constructor_(self, x)
#    1606     x = self._K(x)
#    1607 V, _, embedding = self._K.vector_space()
# -> 1608 if embedding(x) not in self._module_rep:
#    1609     raise TypeError("Not an element of the order.")
#    1610 return self._element_type(self, x)
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/parent.pyx:1171, in sage.structure.parent.Parent.__contains__ (build/cythonized/sage/structure/parent.c:13824)()
#    1169 try:
#    1170     x2 = self(x)
# -> 1171     EQ = (x2 == x)
#    1172     if EQ is True:
#    1173         return True
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/element.pyx:1099, in sage.structure.element.Element.__richcmp__ (build/cythonized/sage/structure/element.c:18305)()
#    1097         return (<Element>self)._richcmp_(other, op)
#    1098     else:
# -> 1099         return coercion_model.richcmp(self, other, op)
#    1100
#    1101 cpdef _richcmp_(left, right, int op):
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/coerce.pyx:2023, in sage.structure.coerce.CoercionModel.richcmp (build/cythonized/sage/structure/coerce.c:26255)()
#    2021 # Coerce to a common parent
#    2022 try:
# -> 2023     x, y = self.canonical_coercion(x, y)
#    2024 except (TypeError, NotImplementedError):
#    2025     pass
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/structure/coerce.pyx:1346, in sage.structure.coerce.CoercionModel.canonical_coercion (build/cythonized/sage/structure/coerce.c:17351)()
#    1344 x_map, y_map = coercions
#    1345 if x_map is not None:
# -> 1346     x_elt = (<Map>x_map)._call_(x)
#    1347 else:
#    1348     x_elt = x
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/categories/map.pyx:827, in sage.categories.map.Map._call_ (build/cythonized/sage/categories/map.c:10627)()
#     825     return self._call_with_args(x, args, kwds)
#     826
# --> 827 cpdef Element _call_(self, x):
#     828     """
#     829     Call method with a single argument, not implemented in the base class.
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/modules/matrix_morphism.py:215, in MatrixMorphism_abstract._call_(self, x)
#     213     x = x.element()
#     214 else:
# --> 215     x = self.domain().coordinate_vector(x)
#     216 C = self.codomain()
#     217 if self.side() == "left":
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/modules/free_module.py:7706, in FreeModule_submodule_pid.coordinate_vector(self, v, check)
#    7677 def coordinate_vector(self, v, check=True):
#    7678     """
#    7679     Write `v` in terms of the user basis for ``self``.
#    7680
#    (...)
#    7704         (5, -1)
#    7705     """
# -> 7706     return self.echelon_coordinate_vector(v, check=check)
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/modules/free_module.py:7556, in FreeModule_submodule_with_basis_pid.echelon_coordinate_vector(self, v, check)
#    7524 def echelon_coordinate_vector(self, v, check=True):
#    7525     """
#    7526     Write `v` in terms of the echelonized basis for ``self``.
#    7527
#    (...)
#    7554         (1, 18)
#    7555     """
# -> 7556     return FreeModule(self.base_ring().fraction_field(), self.rank())(self.echelon_coordinates(v, check=check))
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/modules/free_module.py:7083, in FreeModule_submodule_with_basis_pid.echelon_coordinates(self, v, check)
#    7080 # Next use the transformation matrix from the rref basis
#    7081 # to the echelon basis.
#    7082 T = self._rref_to_echelon_matrix()
# -> 7083 x = T.linear_combination_of_rows(w).list(copy=False)
#    7084 if not check:
#    7085     return x
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/matrix/matrix0.pyx:3965, in sage.matrix.matrix0.Matrix.linear_combination_of_rows (build/cythonized/sage/matrix/matrix0.c:37712)()
#    3963     from sage.matrix.constructor import matrix
#    3964     v = matrix(list(v)+[0]*(self._nrows-len(v)))
# -> 3965     return (v * self)[0]
#    3966
#    3967 def linear_combination_of_columns(self, v):
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/matrix/matrix0.pyx:1083, in sage.matrix.matrix0.Matrix.__getitem__ (build/cythonized/sage/matrix/matrix0.c:12936)()
#    1081     if row < 0 or row >= nrows:
#    1082         raise IndexError("matrix index out of range")
# -> 1083     r = self.row(row)
#    1084
#    1085 r.set_immutable()
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/matrix/matrix_rational_dense.pyx:2862, in sage.matrix.matrix_rational_dense.Matrix_rational_dense.row (build/cythonized/sage/matrix/matrix_rational_dense.cpp:36272)()
#    2860
#    2861         cdef Py_ssize_t j
# -> 2862         parent = self.row_ambient_module()
#    2863         cdef Vector_rational_dense v = Vector_rational_dense.__new__(Vector_rational_dense)
#    2864         v._init(self._ncols, parent)
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/matrix/matrix1.pyx:898, in sage.matrix.matrix1.Matrix.row_ambient_module (build/cythonized/sage/matrix/matrix1.c:15495)()
#     896 if x is not None:
#     897     return x
# --> 898 x = sage.modules.free_module.FreeModule(self._base_ring, self._ncols,
#     899                                         sparse=self.is_sparse_c())
#     900 self.cache('row_ambient_module', x)
#
# File ~/miniconda3/lib/python3.12/site-packages/sage/modules/free_module.py:308, in FreeModule(base_ring, rank_or_basis_keys, sparse, inner_product_matrix, with_basis, rank, basis_keys, **args)
#     302         return FreeModule_ambient(base_ring, rank, sparse=sparse)
#     305 FreeModuleFactory_with_standard_basis = FreeModuleFactory("FreeModule")
# --> 308 def FreeModule(base_ring, rank_or_basis_keys=None, sparse=False, inner_product_matrix=None, *,
#     309                with_basis='standard', rank=None, basis_keys=None, **args):
#     310     r"""
#     311     Create a free module over the given commutative ``base_ring``.
#     312
#    (...)
#     528         ValueError: inconsistent rank: should be cardinality of ['a', 'b'] but got 3
#     529     """
#     530     if rank_or_basis_keys is not None:
#
# File signals.pyx:355, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
